# %%
# !pip install orange3

# %%
import Orange

# "Bow-TFIDF" & 7.8333\\
# "Bow-TF" & 9.3333\\
# "AE" & 6.1667\\
# "Bow-Binary" & 8.6667\\
# "VAE" & 5.0833\\
# "MVAE" & 2.9167\\
# "MAE" & 1.0833\\
# "Maalej" & 4.6667\\
# "DBERTML" & 5.6667\\
# "Density" & 3.5833\\

names = ["Bow-TFIDF", "Bow-TF", "AE", "Bow-Binary", "VAE", "MVAE", 'MAE', '[27]', 'DBERTML', 'Topic']

avranks =  [7.8333, 9.3333, 6.1667, 8.6667, 5.0833, 2.9167, 1.0833, 4.6667, 5.6667, 3.5833]

cd = Orange.evaluation.scoring.compute_CD(avranks, 12) # tested on 12 datasets

Orange.evaluation.scoring.graph_ranks(avranks, names, cd=cd,filename="f1.png")
print(cd)
# Out:
# 3.910418082408125

# %%
# "Bow-TFIDF" & 6.1667\\
# "Bow-TF" & 9.3333\\
# "AE" & 7.25\\
# "Bow-Binary" & 9.6667\\
# "VAE" & 5.1667\\
# "MVAE" & 3\\
# "MAE" & 1.25\\
# "Maalej" & 3.0833\\
# "DBERTML" & 5.6667\\
# "Density" & 4.4167\\

names = ["Bow-TFIDF", "Bow-TF", "AE", "Bow-Binary", "VAE", "MVAE", 'MAE', '[27]', 'DBERTML', 'Topic']

avranks =  [6.1667, 9.3333, 7.25, 9.6667, 5.1667, 3, 1.25, 3.0833, 5.6667, 4.4167]

cd = Orange.evaluation.scoring.compute_CD(avranks, 12) # tested on 12 datasets

Orange.evaluation.scoring.graph_ranks(avranks, names, cd=cd,filename="auc_roc.png")
print(cd)
# Out:
# 3.910418082408125
